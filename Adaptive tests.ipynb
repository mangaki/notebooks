# %%
import pandas as pd
import numpy as np

# Hi JJ
jj = pd.DataFrame(np.array(Rating.objects.filter(user=1).values_list('user_id', 'work_id', 'choice'),
                           dtype=[('user_id', 'i4'), ('work_id', 'i4'), ('choice', 'U25')]))

# %%
jj.head()
# Out:
#    user_id  work_id   choice
# 0        1     1146     like
# 1        1     1875  willsee
# 2        1     2078  willsee
# 3        1        3  wontsee
# 4        1     3117  willsee

# %%
from mangaki.utils.values import rating_values

jj['rating'] = jj['choice'].map(rating_values)
jj.head()
# Out:
#    user_id  work_id   choice  rating
# 0        1     1146     like     2.0
# 1        1     1875  willsee     0.5
# 2        1     2078  willsee     0.5
# 3        1        3  wontsee    -0.5
# 4        1     3117  willsee     0.5

# %%
from mangaki.algo.dataset import Dataset

triplets = Rating.objects.exclude(user_id=1).values_list('user_id', 'work_id', 'choice')
dataset = Dataset()
anonymized = dataset.make_anonymous_data(triplets)

# %%
jj['encoded_user_id'] = jj['user_id'].map(dataset.encode_user)
jj['encoded_work_id'] = jj['work_id'].map(dataset.encode_work)
jj.head()
# Out:
#    user_id  work_id   choice  rating  encoded_user_id  encoded_work_id
# 0        1     1146     like     2.0              NaN            10341
# 1        1     1875  willsee     0.5              NaN             6917
# 2        1     2078  willsee     0.5              NaN             1573
# 3        1        3  wontsee    -0.5              NaN             7888
# 4        1     3117  willsee     0.5              NaN             5324

# %%
X = anonymized.X
y = anonymized.y

# %%
from mangaki.algo.als import MangakiALS

als = MangakiALS()
als.set_parameters(anonymized.nb_users, anonymized.nb_works)
als.fit(X, y)
# Out:
# Computing M: (2139 × 11653)
# Chrono: fill and center matrix [7q, 1113ms]
# Chrono: factor matrix [7q, 8509ms]
# Shapes (2139, 20) (20, 11653)

# %%
y_pred = als.predict(X)
als.compute_rmse(y, y_pred)
# 0.924
# Out:
# 0.92413970001334411

# %%
als.U.shape
# Add a user
als.U = np.vstack((als.U, np.zeros(20)))
als.U.shape
# Out:
# (2141, 20)

# %%
als.means = np.concatenate((als.means, [0]))

# %%
def train_user(user_id, work_ids, ratings):
    NEW_USER_ID = user_id
    als.means[NEW_USER_ID] = ratings.mean()
    Ru = ratings - ratings.mean()
    Vu = als.VT[:, work_ids]
    Gu = als.lambda_ * len(Ru) * np.eye(als.nb_components)
    als.U[[NEW_USER_ID], :] = np.linalg.solve(Vu.dot(Vu.T) + Gu, Vu.dot(Ru)).T

# %%
train_user(2139, jj['encoded_work_id'], jj['rating'])
als.U[2139]
# Out:
# array([-0.14303548, -0.1629117 , -0.09923869, -0.19760937,  0.11942109,
#        -0.32526121,  0.18492868, -0.02383607,  0.1816412 ,  0.03937937,
#         0.02771371,  0.02618218,  0.0556854 ,  0.10054771, -0.02409849,
#        -0.00325536, -0.02481059,  0.114783  ,  0.21336958,  0.03092004])

# %%
als.M = als.U.dot(als.VT)

# %%
jj['encoded_user_id'] = [2139] * len(Ru)

# %%
X_jj = np.array(jj[['encoded_user_id', 'encoded_work_id']]).astype(np.int64)
jj['pred'] = als.predict(X_jj)

# %%
jj.head()
# Out:
#    user_id  work_id   choice  rating  encoded_user_id  encoded_work_id  \
# 0        1     1146     like     2.0             2139            10341
# 1        1     1875  willsee     0.5             2139             6917
# 2        1     2078  willsee     0.5             2139             1573
# 3        1        3  wontsee    -0.5             2139             7888
# 4        1     3117  willsee     0.5             2139             5324
#
#        pred
# 0  0.735778
# 1  1.068240
# 2  0.763262
# 3  0.339925
# 4  0.540148

# %%
als.compute_rmse(jj['rating'], jj['pred'])
# 0.952
# Out:
# 1.0834690333964536

# %%
titles = dict(Work.objects.values_list('id', 'title'))
jj['title'] = jj['work_id'].map(titles)

jj.sort('pred')
# Out:
# /Users/jilljenn/code/mangaki/venv/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   after removing the cwd from sys.path.
#      user_id  work_id    choice  rating  encoded_user_id  encoded_work_id  \
# 395        1      126   willsee     0.5             2139             9183
# 251        1       18   wontsee    -0.5             2139             4305
# 243        1       21   willsee     0.5             2139            11104
# 270        1       75   wontsee    -0.5             2139             9468
# 323        1     5307   wontsee    -0.5             2139            11263
# 29         1        6   dislike    -2.0             2139             1055
# 292        1      143   willsee     0.5             2139             7200
# 315        1     1126   wontsee    -0.5             2139             4619
# 383        1    10365   willsee     0.5             2139             6848
# 608        1     3476   wontsee    -0.5             2139             2843
# 331        1     4372   willsee     0.5             2139             3418
# 391        1     4060   wontsee    -0.5             2139             8267
# 301        1      109   willsee     0.5             2139             5285
# 525        1     2422   willsee     0.5             2139            11046
# 297        1     2018   willsee     0.5             2139             7398
# 609        1     2792   wontsee    -0.5             2139             2900
# 488        1     7511   willsee     0.5             2139             4034
# 353        1       86   willsee     0.5             2139             7915
# 273        1       87   willsee     0.5             2139             1946
# 333        1      118   wontsee    -0.5             2139             3164
# 531        1      732   willsee     0.5             2139             4738
# 198        1     7873      like     2.0             2139             1198
# 3          1        3   wontsee    -0.5             2139             7888
# 356        1     2417   willsee     0.5             2139            11011
# 294        1       66   willsee     0.5             2139              775
# 598        1     1467   wontsee    -0.5             2139            10186
# 467        1     2735   willsee     0.5             2139             1578
# 368        1      107   willsee     0.5             2139             3404
# 547        1     8392   wontsee    -0.5             2139             2020
# 384        1     3555   willsee     0.5             2139             8018
# ..       ...      ...       ...     ...              ...              ...
# 234        1     4117   willsee     0.5             2139             9658
# 263        1     6595      like     2.0             2139            10880
# 539        1    15322   dislike    -2.0             2139             1339
# 216        1     9996   willsee     0.5             2139             5164
# 631        1    14416      like     2.0             2139             8724
# 76         1      958  favorite     4.0             2139             3546
# 427        1      324  favorite     4.0             2139             4122
# 625        1    14755      like     2.0             2139            11177
# 515        1    13524   willsee     0.5             2139             4155
# 193        1     4201   willsee     0.5             2139            10853
# 80         1      410  favorite     4.0             2139             8265
# 124        1     8153      like     2.0             2139             5389
# 540        1    14284  favorite     4.0             2139             5224
# 88         1     1584      like     2.0             2139             6882
# 478        1     6880   willsee     0.5             2139             4002
# 596        1      106   neutral     0.1             2139             2527
# 616        1     2238   willsee     0.5             2139             8890
# 73         1      967      like     2.0             2139            11120
# 502        1     1289      like     2.0             2139             5503
# 81         1       53  favorite     4.0             2139             9018
# 516        1    14297   willsee     0.5             2139             4661
# 641        1    13587   wontsee    -0.5             2139            11502
# 90         1     2768      like     2.0             2139             4176
# 490        1    12200      like     2.0             2139             2566
# 428        1       30  favorite     4.0             2139             3845
# 465        1       60  favorite     4.0             2139             5448
# 517        1    13002   willsee     0.5             2139             8961
# 621        1    14862      like     2.0             2139             5719
# 624        1    14754      like     2.0             2139             3266
# 538        1    14379      like     2.0             2139             5030
#
#          pred                                              title
# 395  0.180609                                     Dragon Ball GT
# 251  0.196237                                         Fairy Tail
# 243  0.208779                             Highschool of the Dead
# 270  0.209681                                    High School DxD
# 323  0.220937                                         Fairy Tail
# 29   0.225559                                             Bleach
# 292  0.236263                                         To LOVE-Ru
# 315  0.240745             Boku wa Tomodachi ga Sukunai Episode 0
# 383  0.254406                                         Kiss x Sis
# 608  0.268238                         Ikkitousen: Dragon Destiny
# 331  0.286312         Attaque Des Titans (l') - Guides officiels
# 391  0.292962   Naruto the Movie 2: Legend of the Stone of Gelel
# 301  0.296878                               IS: Infinite Stratos
# 525  0.305500                        Kuroko no Basket 3rd Season
# 297  0.306416                 The irregular at magic high school
# 609  0.309613       Highschool of the Dead: Drifters of the Dead
# 488  0.322943                         Sword Art Online - Aincrad
# 353  0.324551                                 Is this a Zombie ?
# 273  0.325259                                Sword Art Online II
# 333  0.331484                              Vampire Knight Guilty
# 531  0.333368                                   Strike the Blood
# 198  0.339070                                Vision d'Escaflowne
# 3    0.339925                                   Sword Art Online
# 356  0.343325                              Kuroko's Basketball 2
# 294  0.347960                                 Rosario to Vampire
# 598  0.349468                                       Blade & Soul
# 467  0.352773                                        Ikki Tousen
# 368  0.352961                                   Kuroko no Basket
# 547  0.353195                                            Amnesia
# 384  0.356880                                           Freezing
# ..        ...                                                ...
# 234  1.271464                                  20th century boys
# 263  1.271617                                           Nausicaa
# 539  1.274894                                        Yuri on Ice
# 216  1.278033                                         Cross Road
# 631  1.285106                                      Spirited Away
# 76   1.288729                                    Le Vent se lève
# 427  1.293657                                            Paprika
# 625  1.298330                            Kiki's Delivery Service
# 515  1.299481                                        Dimension W
# 193  1.302488                                              Akira
# 80   1.310537                                        Porco Rosso
# 124  1.314216                         La Colline aux coquelicots
# 540  1.316324                         March Comes in Like a Lion
# 88   1.332472                             Grave of the Fireflies
# 478  1.334648                                              Pluto
# 596  1.335824                                  Mon voisin Totoro
# 616  1.346447                                     A Silent Voice
# 73   1.352435                            Kiki la petite sorcière
# 502  1.389816                      Nausicaä de la vallée du vent
# 81   1.409857                                Le Château ambulant
# 516  1.418666                                        Dimension W
# 641  1.420598                                     Lovely Complex
# 90   1.437438                            Le Château dans le ciel
# 490  1.466477  The Anthem of the Heart -Beautiful Word, Beaut...
# 428  1.472580                                      Spirited Away
# 465  1.474137                                 Princesse Mononoké
# 517  1.507337                         Hibike! Euphonium Specials
# 621  1.510209                                  Princess Mononoke
# 624  1.518889                               Howl's Moving Castle
# 538  1.681807                                     Mob Psycho 100
#
# [649 rows x 8 columns]

# %%
NB_QUESTIONS = 10

# %%
# Random
import random

all_ratings = dict(zip(jj['encoded_work_id'], jj['rating']))
subset = np.random.choice(np.array(jj['encoded_work_id']), NB_QUESTIONS, replace=False)
y_test = np.array([all_ratings[work_id] for work_id in subset])
print(subset)
train_user(2140, subset, y_test)
# Out:
# [1937 4801 2824 2623  715 9177 4034 7087 8724 5547]

# %%
jj.query('encoded_work_id in @subset')
# Out:
#      user_id  work_id   choice  rating  encoded_user_id  encoded_work_id  \
# 65         1      419  dislike    -2.0             2139             2824
# 121        1     1563     like     2.0             2139             7087
# 128        1      746  willsee     0.5             2139             1937
# 157        1     1306  willsee     0.5             2139             4801
# 176        1      781  wontsee    -0.5             2139             2623
# 194        1     6492  willsee     0.5             2139              715
# 266        1      130  wontsee    -0.5             2139             5547
# 411        1     9092  willsee     0.5             2139             9177
# 488        1     7511  willsee     0.5             2139             4034
# 631        1    14416     like     2.0             2139             8724
#
#          pred                                              title
# 65   1.081679                                 Mawaru Penguindrum
# 121  1.192337                               Ponyo sur la falaise
# 128  0.669549  Ghost in the Shell: Stand Alone Complex - Tach...
# 157  0.808459                     Natsume's Book of Friends Four
# 176  0.784534   Ghost in the Shell: Arise - Border:3 Ghost Tears
# 194  1.244463                                            Monster
# 266  0.357207                                           Air Gear
# 411  0.396992                                         Rail Wars!
# 488  0.322943                         Sword Art Online - Aincrad
# 631  1.285106                                      Spirited Away

# %%
als.M = als.U.dot(als.VT)
als.U[2140]
# Out:
# array([-0.88114882, -0.15880069, -0.28525917, -0.36149601, -0.03939813,
#         0.25915399,  0.3786149 ,  0.20925865, -0.14391705, -0.26987842,
#        -0.03866946,  0.32678425,  0.32016272, -0.08749871, -0.196268  ,
#        -0.20794798, -0.25496892,  0.01392694, -0.01202279, -0.95187918])

# %%
X_test = np.column_stack(([2140] * len(subset), subset))
y_pred = als.predict(X_test)
als.compute_rmse(y_test, y_pred)
# Out:
# 0.56242319752559311

# %%
X_test = np.column_stack(([2140] * len(jj['encoded_work_id']), jj['encoded_work_id']))
y_pred = als.predict(X_test)
als.compute_rmse(jj['rating'], y_pred)
# Out:
# 1.2861712207134659

# %%
# DPP

# %%
y.shape
# Out:
# (346210,)

# %%
from mangaki.algo.knn import MangakiKNN

knn = MangakiKNN()
knn.set_parameters(anonymized.nb_users, anonymized.nb_works)
knn.fit(X, y)
L = rbf_kernel(knn.M.T[jj['encoded_work_id']])

# %%
from mangaki.utils.dpplib import decompose_kernel, sample_k
from sklearn.metrics.pairwise import rbf_kernel

L = rbf_kernel(als.VT.T[jj['encoded_work_id']])

# %%
L.shape
# Out:
# (649, 649)

# %%
D, V = decompose_kernel(L)

# %%
# From here
subset_pos = sample_k(NB_QUESTIONS, D, V).reshape(NB_QUESTIONS).astype(np.int64)

# %%
als.means = np.concatenate((als.means, [0]))
als.U = np.vstack((als.U, np.zeros(20)))

# %%
subset = jj['encoded_work_id'][subset_pos]
y_test = np.array([all_ratings[work_id] for work_id in subset])
train_user(2141, subset, y_test)

# %%
jj.query('encoded_work_id in @subset')
# Out:
#      user_id  work_id    choice  rating  encoded_user_id  encoded_work_id  \
# 37         1      134      like     2.0             2139             9655
# 80         1      410  favorite     4.0             2139             8265
# 178        1     9936   willsee     0.5             2139             1776
# 183        1     4369   willsee     0.5             2139             3410
# 273        1       87   willsee     0.5             2139             1946
# 354        1      148   willsee     0.5             2139            11142
# 392        1      877   willsee     0.5             2139             8063
# 411        1     9092   willsee     0.5             2139             9177
# 476        1    14293   willsee     0.5             2139             6702
# 483        1     8242   willsee     0.5             2139             8352
#
#          pred                             title
# 37   1.157036                       Summer Wars
# 80   1.310537                       Porco Rosso
# 178  0.974245                         Cencoroll
# 183  0.739514           Attaque Des Titans (l')
# 273  0.325259               Sword Art Online II
# 354  0.746681  Black Lagoon: The Second Barrage
# 392  0.803639           Goodbye Mr. Despair OAD
# 411  0.396992                        Rail Wars!
# 476  0.876363                   UTAMONOGATARI ♫
# 483  0.591582                  Yona of the Dawn

# %%
als.M = als.U.dot(als.VT)
als.U[2141]
# Out:
# array([-0.01710628, -0.13274005, -0.30822378, -0.22863072,  0.16678263,
#        -0.35646804,  0.5714343 ,  0.21015158,  0.03017136,  0.23297129,
#        -0.05941062,  0.52798474,  0.64742897, -0.19957709, -0.11503318,
#        -0.15056268, -0.39358746,  0.0151542 ,  0.83685526,  0.07839983])

# %%
X_test = np.column_stack(([2141] * len(jj['encoded_work_id']), jj['encoded_work_id']))
y_pred = als.predict(X_test)
als.compute_rmse(jj['rating'], y_pred)
# Out:
# 1.1563861569837124
